# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://forum.12ozprophet.com/topic/77629-oakland-510-east-bay-business/?page=123'

# %%
pages = list(range(121, 123))

# %%
base_url = "https://forum.12ozprophet.com/topic/77629-oakland-510-east-bay-business/?page="
images = set()
for page in pages:
    url = base_url+str(page)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('img', class_= "ipsImage ipsImage_thumbnailed") 
    results = ["http:"+i["src"] for i in results] 
    for result in results:
        images.add(result)
        print(images)
# Out:
# {'http://s3.amazonaws.com/12oz-2018-ipsboard/monthly_2018_06/LMVewtJ.thumb.jpg.1e22f20d53e7a7448a902b9b3c3fbec8.jpg'}
# {'http://s3.amazonaws.com/12oz-2018-ipsboard/monthly_2018_06/LMVewtJ.thumb.jpg.1e22f20d53e7a7448a902b9b3c3fbec8.jpg', 'http://s3.amazonaws.com/12oz-2018-ipsboard/monthly_2018_06/eqzZHML.thumb.jpg.822429e1a7e21f36c5b96c9baf7d500d.jpg'}
# {'http://s3.amazonaws.com/12oz-2018-ipsboard/monthly_2018_06/LMVewtJ.thumb.jpg.1e22f20d53e7a7448a902b9b3c3fbec8.jpg', 'http://s3.amazonaws.com/12oz-2018-ipsboard/monthly_2018_06/eqzZHML.thumb.jpg.822429e1a7e21f36c5b96c9baf7d500d.jpg', 'http://s3.amazonaws.com/12oz-2018-ipsboard/monthly_2018_06/C9kirDI.thumb.jpg.9f10a3706f64c9052a2b5a378e7c2e4b.jpg'}
# ...
